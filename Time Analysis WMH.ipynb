# %%
import pandas as pd

# %%
#df = pd.read_csv('e:/work/logs/caus_2019_01_11_Airport_platoon_change/wmh_2019_01_11_20_03_30.csv')
df = pd.read_csv('e:/work/logs/caus_2019_01_11_Airport_platoon_change/wmh_2019_01_11_19_55_01.csv')

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.plot(df_TX.TmStampMs)

# %%
import numpy as np

# %%
def time_analysis(df,id):
    df_id=df[df.TempId==id]
    now=np.array(df_id.TmStampMs)
    nxt = np.zeros(now.shape)
    nxt[0]=now[0]
    nxt[1:]=now[0:-1]
    plt.plot(nxt-now)

# %%
time_analysis(df,'AB790148')

# %%
time_analysis(df,'A6990148')

# %%
time_analysis(df,'223C0148')
